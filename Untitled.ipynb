# %%
import project_fake_news

# %%
text="osuidhfvoshdfvkiwsbdvkjasbd///????..."

# %%
project_fake_news.wordopt(text)
# Out:
# 'osuidhfvoshdfvkiwsbdvkjasbd          '

# %%
lr,ar,mr,gr=project_fake_news.load_function()

# %%
print(project_fake_news.color.BLUE+"kkhsbfgb"+project_fake_news.color.END)
# Out:
# kkhsbfgb

# %%
print("\033[92m"+'\033[1m'+"Real News"+'\033[0m')
# Out:
# Real News

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fig,((ax1,ax2),(ax3,ax4))=plt.subplots(nrows=2,ncols=2,figsize=(15,10))
ax1.axis('off')
ax1.text(0,0.5,a,verticalalignment="center")
ax1.set(title="The News");

ax2.pie([10,100]);
myexplode=[0.2, 0]
ax3.pie([4,2],labels=["a","b"], explode=myexplode,shadow=True)
fig.
# Out:
# ([<matplotlib.patches.Wedge at 0x1f4c2289880>,
#   <matplotlib.patches.Wedge at 0x1f4c0fb8940>],
#  [Text(-0.650000070272062, 1.1258329843481736, 'a'),
#   Text(0.5500001486524352, -0.9526278583383436, 'b')])

# %%
# s=input("Enter the news")
# i=60
# while i<len(s):
#     if s[i]==" ":
#         s= s[:i]+"\n"+s[i+1:]
#         i=i+60
#     else:
#         i=i+1
# print("\n"+project_fake_news.color.BOLD+"The News"+project_fake_news.color.END)
# print(s)

def news_manager(news):
    '''Manages the news by converting the long single-line news string
    into multi-line news string'''
    if (len(news)>1355):
        news=news[:1355]+"......"
    s=news
    i=60
    while i<len(s):
        if s[i]==" ":
            s= s[:i]+"\n"+s[i+1:]
            i=i+60
        else:
            i=i+1
    return(s)

# %%
news=input("enter the news string")
a=news_manager(news)
print(a)
# Out:
# enter the news stringakjsdfksdbhagf
# akjsdfksdbhagf

# %%
horizontalalignment='center',verticalalignment="center"

# %%
Warning customers against fake SMSes or WhatsApp messages about electricity disconnection, electricity distribution companies of Gujarat such as Torrent Power Friday said both customers and the company’s own employees have been receiving fake messages from fraudsters and miscreants.

In an official statement, Torrent Power said, “Over the past few months, there have been an increasing number of reports of fake SMSes and or WhatsApp messages being sent to consumers across the country by fraudsters or miscreants, claiming that the customer’s power connection would be disconnected at 09:30 or 10.30 PM, as the previous month bill was not updated.”

It added, “In these fake messages, customers are also asked to get in touch with the company officer and a personal mobile number is also mentioned in the message. Torrent Power urges its customers not to respond to any such messages or call the number provided in fake messages.”

“Cautioning customers against such fraudsters, the company would like to inform that the fraudsters pose as call centre executives and then ask unsuspecting citizens to share their bank details and OTP or ask them to download a software which gives the fraudster total control of the customer’s mobile or laptop, enabling them to steal banking-related information and carry out fraudulent transactions,” the statement added. Torrent Power supplies electricity to Ahmedabad, Gandhinagar and Surat cities in the state.

# %%
dic={"a":1,
    "b":12,
    "c":13,
    "d2":2}

# %%
dic
# Out:
# {'a': 1, 'b': 12, 'c': 13, 'd2': 2}

# %%
import pandas as pd

# %%
df_score=pd.read_csv("./data/df_score.csv")

# %%
df_score
# Out:
#    Logistic Regression  Decision Tree  Greadent Boost  Random Forest
# 0            98.101604      95.614973       97.156863      97.780749

# %%
import matplotlib.pyplot as plt

# %%
df_score.T.plot(kind="barh",legend=False,color="maroon")
# Out:
# <AxesSubplot:>

# %%
plt.bar([df_score["Logistic Regression"],df_score["Decision Tree"],df_score["Greadent Boost"],df_score["Random Forest"]],["LR","DT","GBC","RFC"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\SAHEBM~1\AppData\Local\Temp/ipykernel_6212/3557508837.py in <module>
# ----> 1 plt.bar([df_score["Logistic Regression"],df_score["Decision Tree"],df_score["Greadent Boost"],df_score["Random Forest"]],["LR","DT","GBC","RFC"])
#
# d:\sample_project_1\env\lib\site-packages\matplotlib\pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2385         x, height, width=0.8, bottom=None, *, align='center',
#    2386         data=None, **kwargs):
# -> 2387     return gca().bar(
#    2388         x, height, width=width, bottom=bottom, align=align,
#    2389         **({"data": data} if data is not None else {}), **kwargs)
#
# d:\sample_project_1\env\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1410     def inner(ax, *args, data=None, **kwargs):
#    1411         if data is None:
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1413
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
# d:\sample_project_1\env\lib\site-packages\matplotlib\axes\_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2393                    hatch)
#    2394         for l, b, w, h, c, e, lw, htch in args:
# -> 2395             r = mpatches.Rectangle(
#    2396                 xy=(l, b), width=w, height=h,
#    2397                 facecolor=c,
#
# d:\sample_project_1\env\lib\site-packages\matplotlib\patches.py in __init__(self, xy, width, height, angle, **kwargs)
#     725             %(Patch:kwdoc)s
#     726         """
# --> 727         super().__init__(**kwargs)
#     728         self._x0 = xy[0]
#     729         self._y0 = xy[1]
#
# d:\sample_project_1\env\lib\site-packages\matplotlib\patches.py in __init__(self, edgecolor, facecolor, color, linewidth, linestyle, antialiased, hatch, fill, capstyle, joinstyle, **kwargs)
#     104         self.set_fill(fill)
#     105         self.set_linestyle(linestyle)
# --> 106         self.set_linewidth(linewidth)
#     107         self.set_antialiased(antialiased)
#     108         self.set_hatch(hatch)
#
# d:\sample_project_1\env\lib\site-packages\matplotlib\patches.py in set_linewidth(self, w)
#     409                 w = mpl.rcParams['axes.linewidth']
#     410
# --> 411         self._linewidth = float(w)
#     412         # scale the dash pattern by the linewidth
#     413         offset, ls = self._us_dashes
#
# TypeError: only size-1 arrays can be converted to Python scalars

# %%
df_score
# Out:
#    Logistic Regression  Decision Tree  Greadent Boost  Random Forest
# 0            98.101604      95.614973       97.156863      97.780749

# %%
dic=df_score.to_dict()

# %%
dic
# Out:
# {'Logistic Regression': {0: 98.10160427807486},
#  'Decision Tree': {0: 95.6149732620321},
#  'Greadent Boost': {0: 97.15686274509804},
#  'Random Forest': {0: 97.7807486631016}}

# %%
dic["Logistic Regression"][0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\SAHEBM~1\AppData\Local\Temp/ipykernel_6212/155980115.py in <module>
# ----> 1 dic[0][0]
#
# KeyError: 0

# %%
score_value=[]
model_name=[]
for i in dic.keys():
    score_value.append(dic[i][0])
    model_name.append(i)
score_value,model_name
# Out:
# ([98.10160427807486, 95.6149732620321, 97.15686274509804, 97.7807486631016],
#  ['Logistic Regression', 'Decision Tree', 'Greadent Boost', 'Random Forest'])

# %%
plt.style.use("fivethirtyeight")
plt.barh(model_name,score_value,color=["salmon","lightblue","teal","pink"])
for index, value in enumerate(score_value):
    plt.text(value, index,str(value)+"%")

# %%
for index, value in enumerate(score_value):
    plt.text(value, index,str(value))
